# %% [markdown]
# <a href="https://colab.research.google.com/github/FaridaBey/Assignment/blob/main/Labs/Lab4/Lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment: Text Generation with RNNs
#
# In this assignment, you will explore text generation using deep learning models, specifically Recurrent Neural Networks (RNNs). Text generation is a fascinating task where the goal is to train a model that can predict the next word in a sequence, ultimately generating coherent and contextually accurate sentences or paragraphs.
#
# You will work with a corpus of text data provided in the tutorial (from TensorFlow), which contains a large collection of Shakespeare’s works. Your objective is to implement a text generation model using RNNs and to evaluate its performance based on various metrics.
#
# <img src="https://drek4537l1klr.cloudfront.net/teofili2/Figures/03fig09_alt.jpg" alt="Drawing"/>
#
# **The models include:**
# - Deep RNN (LSTM)
# - Deep RNN (GRU)
# - Bidirectional RNN
#
#
# **Evaluation:**
#
# Evaluate the performance of the text generation model using several metrics:
# - Perplexity: A measure of how well the probability distribution predicted by the model aligns with the actual distribution of words in the text.
# - Generated Text Quality: Subjectively evaluate the quality of the generated text by considering grammar, coherence, and creativity. This can be done by visually inspecting the generated sequences.
# - BLUE Score: Character-level BLEU: BLEU can be applied at the character level by treating each character as an n-gram. This is particularly useful when the task involves generating character sequences (like poetry, code, or fine-grained character-based generation).
# For example, the sequence “hello” could be evaluated by comparing 1-grams (e.g., “h”, “e”, “l”, “l”, “o”) or higher-order n-grams (e.g., “he”, “el”, “ll”, “lo”).
#
# **Goals:**
#
# - Compare the performance of GRU and LSTM. Is there a significant difference in the results?
# - Compare the performance of the unidirectional and bidirectional RNN models.
# Which model produces better results?
# - Discuss the impact of bidirectional RNNs on text generation tasks.

# %% [markdown]
# # Import TensorFlow and other libraries

# %%
import tensorflow as tf
import numpy as np
import nltk
from nltk.translate.bleu_score import sentence_bleu
import os
import time

# %% [markdown]
# # Dataset

# %% [markdown]
# The Shakespeare dataset used for text generation contains a collection of works by William Shakespeare, primarily in the form of plays and sonnets. The text is used to train language models, offering an ideal example for character-level modeling due to its rich, complex language. The dataset is often preprocessed by tokenizing it into individual characters, enabling models to learn the sequential relationships between characters for generating coherent and contextually appropriate text.
#
# To access the dataset, you can use TensorFlow's get_file method as follow:
#
# You can inspect the dataset on [Kaggle](https://www.kaggle.com/datasets/adarshpathak/shakespeare-text/data).

# %%
path_to_file = tf.keras.utils.get_file('shakespeare.txt', 'https://storage.googleapis.com/download.tensorflow.org/data/shakespeare.txt')

# Read, then decode for py2 compat.
text = open(path_to_file, 'rb').read().decode(encoding='utf-8')
# length of text is the number of characters in it
print(f'Length of text: {len(text)} characters')
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/shakespeare.txt
# 1115394/1115394 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Length of text: 1115394 characters

# %%
# Take a look at the first 250 characters in text
print(text[:250])
# Out:
# First Citizen:
# Before we proceed any further, hear me speak.
#
# All:
# Speak, speak.
#
# First Citizen:
# You are all resolved rather to die than to famish?
#
# All:
# Resolved. resolved.
#
# First Citizen:
# First, you know Caius Marcius is chief enemy to the people.

# %% [markdown]
# # Process the text

# %% [markdown]
# ### Vectorize the text
#
# Before training, you need to convert the strings to a numerical representation.
#
# The `tf.keras.layers.StringLookup` layer can convert each character into a numeric ID. It just needs the text to be split into tokens first.

# %%
example_texts = ['abcdefg', 'xyz']

chars = tf.strings.unicode_split(example_texts, input_encoding='UTF-8')
chars
# Out:
# <tf.RaggedTensor [[b'a', b'b', b'c', b'd', b'e', b'f', b'g'], [b'x', b'y', b'z']]>

# %% [markdown]
# Now create the [`tf.keras.layers.StringLookup`](https://www.tensorflow.org/api_docs/python/tf/keras/layers/StringLookup) layer:
#
# Since the goal of this assignment is to generate text, it will also be important to invert this representation and recover human-readable strings from it. For this you can use tf.keras.layers.StringLookup(..., invert=True).
#
# Note: Here instead of passing the original vocabulary generated with sorted(set(text)) use the get_vocabulary() method of the tf.keras.layers.StringLookup layer so that the [UNK] tokens is set the same way.

# %%
def get_string_lookup_layers(vocab):
    """
    Creates StringLookup layers for encoding characters to IDs and decoding IDs back to characters.

    Args:
        vocab (list): List of unique characters in the dataset.

    Returns:
        ids_from_chars (tf.keras.layers.StringLookup): Converts characters to IDs.
        chars_from_ids (tf.keras.layers.StringLookup): Converts IDs back to characters.
    """
    ids_from_chars = tf.keras.layers.StringLookup(
        vocabulary=vocab,
        mask_token=None)
    chars_from_ids = tf.keras.layers.StringLookup(
        vocabulary=ids_from_chars.get_vocabulary(),
        invert=True,
        mask_token=None)
    return ids_from_chars, chars_from_ids

# %%
def text_from_ids(ids, chars_from_ids):
    """
    Converts a sequence of character IDs into a human-readable string.

    Args:
        ids (tf.Tensor): Tensor of character IDs.
        chars_from_ids (tf.keras.layers.StringLookup): StringLookup layer to decode IDs.

    Returns:
        tf.Tensor: Decoded string.
    """
    return tf.strings.reduce_join(chars_from_ids(ids), axis=-1)

# %% [markdown]
# # Create training examples and targets

# %% [markdown]
# Next divide the text into example sequences. Each input sequence will contain seq_length characters from the text.
#
# For each input sequence, the corresponding targets contain the same length of text, except shifted one character to the right.
#
# So break the text into chunks of seq_length+1. For example, say seq_length is 4 and our text is "Hello". The input sequence would be "Hell", and the target sequence "ello".
#
# To do this first use the tf.data.Dataset.from_tensor_slices function to convert the text vector into a stream of character indices.

# %% [markdown]
# For training you'll need a dataset of (input, label) pairs. Where input and label are sequences. At each time step the input is the current character and the label is the next character.
#
# Here's a function that takes a sequence as input, duplicates, and shifts it to align the input and label for each timestep:

# %%
def split_input_target(sequence):
    input_text = sequence[:-1]
    target_text = sequence[1:]
    return input_text, target_text

# %% [markdown]
# Convert Text to Numerical Sequences

# %%
# Initialize mapping layers
vocab = sorted(set(text))
ids_from_chars, chars_from_ids = get_string_lookup_layers(vocab)



# Convert text to character IDs
all_ids = ids_from_chars(tf.strings.unicode_split(text, 'UTF-8'))

# Create a dataset from the character IDs
ids_dataset = tf.data.Dataset.from_tensor_slices(all_ids)

# %% [markdown]
# Create Sequences for Training

# %%
seq_length = 100  # Length of each training sequence

# Batch sequences (each sequence is seq_length + 1)
sequences = ids_dataset.batch(seq_length + 1, drop_remainder=True)

# Map dataset to input-target format
dataset = sequences.map(split_input_target)

# Print sample input-output pairs
for input_example, target_example in dataset.take(1):
    print("Input :", tf.strings.reduce_join(chars_from_ids(input_example)).numpy().decode('utf-8'))
    print("Target:", tf.strings.reduce_join(chars_from_ids(target_example)).numpy().decode('utf-8'))
# Out:
# Input : First Citizen:
# Before we proceed any further, hear me speak.
#
# All:
# Speak, speak.
#
# First Citizen:
# You
# Target: irst Citizen:
# Before we proceed any further, hear me speak.
#
# All:
# Speak, speak.
#
# First Citizen:
# You

# %% [markdown]
# # Create RNN Models

# %% [markdown]
# Before training our text generation models, we need to set up key parameters and prepare the dataset. These parameters control the size of batches, buffer size for shuffling, embedding dimensions, and the number of units in the recurrent layer.

# %% [markdown]
# Customizing Parameters for Optimization
#
# - Increase RNN_UNITS if the model is underfitting (not capturing enough detail).
# - Decrease BATCH_SIZE if memory usage is too high (e.g., when using large RNN units).
# - Adjust EMBEDDING_DIM to experiment with the quality of learned character representations.
#
# Tip: Start with these values, then fine-tune based on model performance and available computational resources!

# %%
BATCH_SIZE = 64
BUFFER_SIZE = 10000
VOCAB_SIZE = len(vocab) + 1
DATASET_SIZE = sum(1 for _ in dataset)

shuffled_dataset = dataset.shuffle(BUFFER_SIZE)

train_dataset = shuffled_dataset.take(int(0.9 * DATASET_SIZE) )
val_dataset = shuffled_dataset.skip(int(0.1 * DATASET_SIZE) )

# Prepare dataset for training
training_dataset = (train_dataset
                 .batch(BATCH_SIZE, drop_remainder=True)
                 .prefetch(tf.data.experimental.AUTOTUNE))
# Prepare dataset for validation
validation_dataset = (val_dataset
               .batch(BATCH_SIZE, drop_remainder=True)
               .prefetch(tf.data.experimental.AUTOTUNE))

# %% [markdown]
# # LSTM-Based Model

# %% [markdown]
# Long Short-Term Memory (LSTM) is a type of Recurrent Neural Network (RNN) designed to capture long-range dependencies in sequential data. Unlike traditional RNNs, which struggle with vanishing gradients, LSTMs use gates (input, forget, and output gates) to regulate the flow of information, making them highly effective for text generation tasks.
#
# This function defines an LSTM-based neural network for text generation.
#
# **Function Overview:**
# * [`tf.keras.layers.Embedding`](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Embedding): This is the input layer, consisting of a trainable lookup table that maps the numbers of each character to a vector with `embedding_dim` dimensions.
# * [`tf.keras.layers.LSTM`](https://www.tensorflow.org/api_docs/python/tf/keras/layers/LSTM): Our LSTM network, with size `units=rnn_units`.
# * [`tf.keras.layers.Dense`](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense): The output layer, with `vocab_size` outputs.
#
#
# <img src="https://raw.githubusercontent.com/aamini/introtodeeplearning/2019/lab1/img/lstm_unrolled-01-01.png" alt="Drawing"/>

# %%
def build_lstm_model(vocab_size, embedding_dim, rnn_units, batch_size):
  """TO DO"""
  """
    Builds an LSTM-based text generation model.

    Parameters:
    - vocab_size (int): Number of unique characters in the vocabulary.
    - embedding_dim (int): Dimension of the word/character embeddings.
    - rnn_units (int): Number of units in the LSTM layer.
    - batch_size (int): Number of sequences processed in parallel.

    Returns:
    - tf.keras.Model: Compiled LSTM model.
    """
  model = tf.keras.Sequential([
        tf.keras.layers.Input(batch_shape=(batch_size, None)),
        tf.keras.layers.Embedding(input_dim=vocab_size, output_dim=embedding_dim),
        tf.keras.layers.LSTM(
            units=rnn_units,
            return_sequences=True,
            stateful=True,
            recurrent_initializer='glorot_uniform'
        ),
        tf.keras.layers.Dense(vocab_size)
    ])
  return model

# %% [markdown]
# **Customization & Optimization**
#
# These experiments are required to improve model performance. You must conduct the following experiments and document your findings:
#
# - Increase RNN_UNITS : This enhances the model’s ability to recognize deeper patterns but may increase training time.
# - Experiment with EMBEDDING_DIM : Adjusting this can improve the quality of character representation.
# - Stack multiple LSTM layers : This can help the model understand text more effectively.
#
# **Submission Requirements**
#
# - Perform at least three trials varying the parameters above.
# - Keep the most performing plots and outputs in your Jupyter Notebook.

# %%
def build_stacked_lstm_model(vocab_size, embedding_dim, rnn_units, batch_size):
    """
    Builds a stacked (deep) LSTM model with multiple LSTM layers.
    """
    model = tf.keras.Sequential([
        tf.keras.layers.Input(batch_shape=(batch_size, None)),
        tf.keras.layers.Embedding(input_dim=vocab_size, output_dim=embedding_dim),
        tf.keras.layers.LSTM(
            units=rnn_units,
            return_sequences=True,   # Must be True to feed into next LSTM
            stateful=True,
            recurrent_initializer='glorot_uniform'
        ),
        tf.keras.layers.LSTM(
            units=rnn_units,
            return_sequences=True,   # Keep True for sequence output
            stateful=True,
            recurrent_initializer='glorot_uniform'
        ),
        tf.keras.layers.Dense(vocab_size)
    ])
    return model

# %% [markdown]
# # GRU-Based Model

# %% [markdown]
# What is GRU?
#
# Gated Recurrent Units (GRU) are a simplified version of LSTMs that combine the forget and input gates into a single update gate. This makes GRUs:
#
# - Faster and more efficient than LSTMs
# - Perform well on shorter sequences
# - Require fewer computational resources
#
# **Model Comparison (LSTM vs. GRU)**
#
# To evaluate the differences between LSTM and GRU models, compare them using:
#
# - Model Size & Number of Parameters : Use model.summary() to check the number of trainable parameters in each model.
# - Training Speed & Efficiency : Measure training time per epoch for both models.

# %%
def build_gru_model(vocab_size, embedding_dim, rnn_units, batch_size):
    """TO DO"""
    """
    Builds a GRU-based text generation model.

    Parameters:
    - vocab_size (int): Number of unique characters in the vocabulary.
    - embedding_dim (int): Dimension of the word/character embeddings.
    - rnn_units (int): Number of units in the GRU layer.
    - batch_size (int): Number of sequences processed in parallel.

    Returns:
    - tf.keras.Model: Compiled GRU model.
    """
    model = tf.keras.Sequential([
        tf.keras.layers.Input(batch_shape=(batch_size, None)),
        tf.keras.layers.Embedding(
            input_dim=vocab_size,
            output_dim=embedding_dim,
        ),
        tf.keras.layers.GRU(
            units=rnn_units,
            return_sequences=True,
            stateful=True,
            recurrent_initializer='glorot_uniform'
        ),
        tf.keras.layers.Dense(vocab_size)
    ])
    return model

# %% [markdown]
# # Bidirectional Model
#
#
# <img src="https://www.researchgate.net/publication/342646275/figure/fig4/AS:962238546464790@1606426955772/Comparison-between-LSTM-and-Bi-LSTM-networks-recreated-after-33.png" alt="Drawing"/>

# %% [markdown]
# **What is Bidirectional RNN?**
#
# A Bidirectional Recurrent Neural Network (BiRNN) is an extension of a standard RNN that processes input sequences in both forward and backward directions. This means that at each time step, the model considers both past (left-to-right) and future (right-to-left) context, leading to better performance in many sequence-related tasks, including text generation.
#
# **Why Use Bidirectional RNNs?**
#
# Bidirectional RNNs are used because they capture dependencies in the input data from both directions, which is crucial for understanding context. This makes them particularly useful in tasks like language processing, where the meaning of a word can depend on both the words that come before and after it.
#
# For example, in the sentence "The cat sat on the mat," the word "mat" is influenced by both the preceding words ("The cat sat on the") and what could potentially follow (e.g., "and looked at the mouse").
#
# Example
#
# Let's consider a sentence: "He opened the door."
#
# Simple RNN: It processes the sentence from left to right, word by word:
#
# He → opened → the → door
# Each word is processed based on the previous word.
#
# Bidirectional RNN: It processes the sentence in both directions:
#
# Forward pass: He → opened → the → door
#
# Backward pass: door → the → opened → He
#
# The output at each time step is a combination of the information from both the forward and backward passes, allowing the network to understand the context better. For instance, knowing that "door" follows "the" helps confirm that "opened" likely refers to a physical action, not a metaphorical one.

# %% [markdown]
# **Choosing the Base RNN for Bidirectional Processing:**
#
# One key flexibility of Bidirectional RNNs is that you can choose any recurrent architecture (LSTM, GRU, Simple RNN) as the base model.
#
# - Bidirectional LSTM: Best for handling long-range dependencies.
# - Bidirectional GRU: More computationally efficient than LSTM.
# - Bidirectional Simple RNN: Less commonly used due to vanishing gradient issues.
#
# Note: To determine the best base model for the Bidirectional RNN, you must evaluate the results from your previous experiments with different architectures (eg. LSTM and GRU).
#
# Review previous results from training LSTM and GRU models.
# Compare their performance in terms of:
#
# - Training time per epoch
# - Model size (number of parameters)
# - Loss and accuracy on validation data
# - Quality of generated text
#
# Based on your findings, select the best-performing model as the base architecture for the Bidirectional RNN.

# %%
def build_birnn_model(vocab_size, embedding_dim, rnn_units, batch_size, rnn_type="LSTM"):
    """TO DO"""
    """
    Builds a Bidirectional RNN-based text generation model.

    Parameters:
    - vocab_size (int): Number of unique characters in the vocabulary.
    - embedding_dim (int): Dimension of the word/character embeddings.
    - rnn_units (int): Number of units in the RNN layer.
    - batch_size (int): Number of sequences processed in parallel.
    - rnn_type (str): Type of RNN to use as the base (options: "LSTM", "GRU").

    Returns:
    - tf.keras.Model: Compiled Bidirectional RNN model.
    """
    # Select base RNN cell type
    if rnn_type == "LSTM":
        rnn_layer = tf.keras.layers.LSTM(
            units=rnn_units,
            return_sequences=True,
            stateful=True,
            recurrent_initializer='glorot_uniform'
        )
    elif rnn_type == "GRU":
        rnn_layer = tf.keras.layers.GRU(
            units=rnn_units,
            return_sequences=True,
            stateful=True,
            recurrent_initializer='glorot_uniform'
        )
    else:
        raise ValueError("rnn_type must be 'LSTM' or 'GRU'")

    model = tf.keras.Sequential([
        tf.keras.layers.Input(batch_shape=(batch_size, None)),
        tf.keras.layers.Embedding(
            input_dim=vocab_size,
            output_dim=embedding_dim,
        ),
        tf.keras.layers.Bidirectional(rnn_layer),
        tf.keras.layers.Dense(vocab_size)
    ])
    return model

# %% [markdown]
# # Evaluating the Models

# %%
trials = [
    {"name": "Trial 1 - Baseline",        "embedding_dim": 256, "rnn_units": 512},
    {"name": "Trial 2 - Larger Units",     "embedding_dim": 256, "rnn_units": 1024},
    {"name": "Trial 3 - Larger Embedding", "embedding_dim": 512, "rnn_units": 512},
]

trial_histories = []

def loss(labels, logits):
    return tf.keras.losses.sparse_categorical_crossentropy(labels, logits, from_logits=True)

for trial in trials:
    print(f"\nRunning {trial['name']} | EMBEDDING_DIM={trial['embedding_dim']}, RNN_UNITS={trial['rnn_units']}")
    m = build_lstm_model(VOCAB_SIZE, trial["embedding_dim"], trial["rnn_units"], BATCH_SIZE)
    m.compile(optimizer='adam', loss=loss)
    h = m.fit(training_dataset, validation_data=validation_dataset, epochs=20)
    trial_histories.append(h)

import matplotlib.pyplot as plt

# Plot trials
plt.figure(figsize=(10, 4))
for h, trial in zip(trial_histories, trials):
    plt.plot(h.history['val_loss'], label=trial["name"])
plt.xlabel('Epoch')
plt.ylabel('Validation Loss')
plt.title('Trial Comparison - Validation Loss')
plt.legend()
plt.show()
# Out:
# Running Trial 1 - Baseline | EMBEDDING_DIM=256, RNN_UNITS=512
# Epoch 1/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 16s 77ms/step - loss: 2.5136 - val_loss: 2.0859
# Epoch 2/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 12s 57ms/step - loss: 1.9424 - val_loss: 1.8227
# Epoch 3/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 11s 58ms/step - loss: 1.7493 - val_loss: 1.6809
# Epoch 4/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 11s 59ms/step - loss: 1.6396 - val_loss: 1.5918
# Epoch 5/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 10s 56ms/step - loss: 1.5651 - val_loss: 1.5294
# Epoch 6/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 24s 74ms/step - loss: 1.5148 - val_loss: 1.4842
# Epoch 7/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 13s 62ms/step - loss: 1.4739 - val_loss: 1.4473
# Epoch 8/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 18s 56ms/step - loss: 1.4423 - val_loss: 1.4198
# Epoch 9/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 11s 59ms/step - loss: 1.4172 - val_loss: 1.3954
# Epoch 10/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 11s 61ms/step - loss: 1.3962 - val_loss: 1.3748
# Epoch 11/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 10s 56ms/step - loss: 1.3768 - val_loss: 1.3563
# Epoch 12/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 21s 54ms/step - loss: 1.3592 - val_loss: 1.3394
# Epoch 13/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 11s 56ms/step - loss: 1.3441 - val_loss: 1.3242
# Epoch 14/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - loss: 1.3302 - val_loss: 1.3145
# Epoch 15/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 11s 58ms/step - loss: 1.3187 - val_loss: 1.2963
# Epoch 16/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 11s 59ms/step - loss: 1.3057 - val_loss: 1.2870
# Epoch 17/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 10s 55ms/step - loss: 1.2948 - val_loss: 1.2728
# Epoch 18/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 12s 63ms/step - loss: 1.2841 - val_loss: 1.2612
# Epoch 19/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 10s 54ms/step - loss: 1.2739 - val_loss: 1.2555
# Epoch 20/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 11s 54ms/step - loss: 1.2642 - val_loss: 1.2417
#
# Running Trial 2 - Larger Units | EMBEDDING_DIM=256, RNN_UNITS=1024
# Epoch 1/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 24s 133ms/step - loss: 2.4305 - val_loss: 1.9637
# Epoch 2/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 132ms/step - loss: 1.7954 - val_loss: 1.6546
# Epoch 3/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 127ms/step - loss: 1.5869 - val_loss: 1.5042
# Epoch 4/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 129ms/step - loss: 1.4752 - val_loss: 1.4226
# Epoch 5/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 130ms/step - loss: 1.4086 - val_loss: 1.3620
# Epoch 6/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 132ms/step - loss: 1.3599 - val_loss: 1.3147
# Epoch 7/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 131ms/step - loss: 1.3213 - val_loss: 1.2784
# Epoch 8/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 129ms/step - loss: 1.2869 - val_loss: 1.2449
# Epoch 9/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 130ms/step - loss: 1.2558 - val_loss: 1.2121
# Epoch 10/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 130ms/step - loss: 1.2259 - val_loss: 1.1823
# Epoch 11/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 132ms/step - loss: 1.1970 - val_loss: 1.1485
# Epoch 12/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 128ms/step - loss: 1.1680 - val_loss: 1.1174
# Epoch 13/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 129ms/step - loss: 1.1386 - val_loss: 1.0877
# Epoch 14/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 129ms/step - loss: 1.1086 - val_loss: 1.0528
# Epoch 15/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 134ms/step - loss: 1.0772 - val_loss: 1.0207
# Epoch 16/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 129ms/step - loss: 1.0466 - val_loss: 0.9883
# Epoch 17/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 129ms/step - loss: 1.0132 - val_loss: 0.9560
# Epoch 18/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 130ms/step - loss: 0.9806 - val_loss: 0.9206
# Epoch 19/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 132ms/step - loss: 0.9474 - val_loss: 0.8870
# Epoch 20/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 129ms/step - loss: 0.9158 - val_loss: 0.8529
#
# Running Trial 3 - Larger Embedding | EMBEDDING_DIM=512, RNN_UNITS=512
# Epoch 1/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 13s 68ms/step - loss: 2.4466 - val_loss: 2.0213
# Epoch 2/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 1.8799 - val_loss: 1.7607
# Epoch 3/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 1.6936 - val_loss: 1.6234
# Epoch 4/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 1.5884 - val_loss: 1.5455
# Epoch 5/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 1.5236 - val_loss: 1.4901
# Epoch 6/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - loss: 1.4762 - val_loss: 1.4462
# Epoch 7/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 1.4410 - val_loss: 1.4136
# Epoch 8/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 1.4124 - val_loss: 1.3876
# Epoch 9/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 1.3885 - val_loss: 1.3659
# Epoch 10/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 1.3688 - val_loss: 1.3483
# Epoch 11/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 1.3508 - val_loss: 1.3309
# Epoch 12/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 13s 70ms/step - loss: 1.3360 - val_loss: 1.3150
# Epoch 13/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 12s 64ms/step - loss: 1.3211 - val_loss: 1.3005
# Epoch 14/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 12s 64ms/step - loss: 1.3085 - val_loss: 1.2879
# Epoch 15/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 1.2955 - val_loss: 1.2740
# Epoch 16/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 20s 64ms/step - loss: 1.2834 - val_loss: 1.2625
# Epoch 17/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 1.2721 - val_loss: 1.2527
# Epoch 18/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 1.2624 - val_loss: 1.2404
# Epoch 19/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 1.2499 - val_loss: 1.2290
# Epoch 20/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 12s 64ms/step - loss: 1.2410 - val_loss: 1.2169
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3003/1527925664.py in <cell line: 0>()
#      18
#      19 # Plot trials
# ---> 20 plt.figure(figsize=(10, 4))
#      21 for h, trial in zip(trial_histories, trials):
#      22     plt.plot(h.history['val_loss'], label=trial["name"])
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt

# Plot trials
plt.figure(figsize=(10, 4))
for h, trial in zip(trial_histories, trials):
    plt.plot(h.history['val_loss'], label=trial["name"])
plt.xlabel('Epoch')
plt.ylabel('Validation Loss')
plt.title('Trial Comparison - Validation Loss')
plt.legend()
plt.show()

# %%
# Based on trial results
EMBEDDING_DIM = 256
RNN_UNITS = 1024

# %% [markdown]
# Model Selection

# %% [markdown]
# Compile & Train the Model

# %%
def compile_and_train(model, path, EPOCHS = 30):
  # Define loss function
  def loss(labels, logits):
    return tf.keras.losses.sparse_categorical_crossentropy(labels, logits, from_logits=True)

  # Compile the model
  model.compile(optimizer='adam', loss=loss)

  # Ensure checkpoint directory exists
  checkpoint_dir = f'./{path}'
  os.makedirs(checkpoint_dir, exist_ok=True)

  checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt_{epoch}")

  checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_prefix + '.weights.h5',
    save_weights_only=True
  )

  # Train the model
  history = model.fit(
    training_dataset,
    validation_data=validation_dataset,
    epochs=EPOCHS,
    callbacks=[checkpoint_callback]
)

  return history

# %%
model_lstm = build_lstm_model(VOCAB_SIZE, EMBEDDING_DIM, RNN_UNITS, BATCH_SIZE)
model_gru = build_gru_model(VOCAB_SIZE, EMBEDDING_DIM, RNN_UNITS, BATCH_SIZE)
model_birnn = build_birnn_model(VOCAB_SIZE, EMBEDDING_DIM, RNN_UNITS, BATCH_SIZE)

# %%
print("=== LSTM Model Summary ===")
model_lstm.summary()

print("\n=== GRU Model Summary ===")
model_gru.summary()

print("\n=== BiRNN Model Summary ===")
model_birnn.summary()
# Out:
# === LSTM Model Summary ===
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_7 (Embedding)         │ (64, None, 256)        │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_7 (LSTM)                   │ (64, None, 1024)       │     5,246,976 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (64, None, 66)         │        67,650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,331,522 (20.34 MB)
#  Trainable params: 5,331,522 (20.34 MB)
#  Non-trainable params: 0 (0.00 B)
# === GRU Model Summary ===
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_8 (Embedding)         │ (64, None, 256)        │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru (GRU)                       │ (64, None, 1024)       │     3,938,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (64, None, 66)         │        67,650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,022,850 (15.35 MB)
#  Trainable params: 4,022,850 (15.35 MB)
#  Non-trainable params: 0 (0.00 B)
# === BiRNN Model Summary ===
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_9 (Embedding)         │ (64, None, 256)        │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (64, None, 2048)       │    10,493,952 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (64, None, 66)         │       135,234 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,646,082 (40.61 MB)
#  Trainable params: 10,646,082 (40.61 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# LSTM
start = time.time()
history_lstm = compile_and_train(model_lstm, path="lstm_checkpoints", EPOCHS=20)
lstm_time = time.time() - start
print(f"LSTM Total Training Time: {lstm_time:.2f}s | Avg per epoch: {lstm_time/20:.2f}s")

# GRU
start = time.time()
history_gru = compile_and_train(model_gru, path="gru_checkpoints", EPOCHS=20)
gru_time = time.time() - start
print(f"GRU Total Training Time: {gru_time:.2f}s | Avg per epoch: {gru_time/20:.2f}s")

# BiRNN
start = time.time()
history_birnn = compile_and_train(model_birnn, path="birnn_checkpoints", EPOCHS=20)
birnn_time = time.time() - start
print(f"BiRNN Total Training Time: {birnn_time:.2f}s | Avg per epoch: {birnn_time/20:.2f}s")

# Summary table
print("\n=== Training Time Comparison ===")
print(f"{'Model':<10} {'Total Time (s)':<20} {'Avg/Epoch (s)':<15}")
print(f"{'LSTM':<10} {lstm_time:<20.2f} {lstm_time/20:<15.2f}")
print(f"{'GRU':<10} {gru_time:<20.2f} {gru_time/20:<15.2f}")
print(f"{'BiRNN':<10} {birnn_time:<20.2f} {birnn_time/20:<15.2f}")
# Out:
# Epoch 1/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 126ms/step - loss: 2.6329 - val_loss: 2.1764
# Epoch 2/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 23s 135ms/step - loss: 2.0062 - val_loss: 1.8608
# Epoch 3/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 132ms/step - loss: 1.7719 - val_loss: 1.6836
# Epoch 4/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 127ms/step - loss: 1.6338 - val_loss: 1.5760
# Epoch 5/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 132ms/step - loss: 1.5469 - val_loss: 1.5023
# Epoch 6/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 131ms/step - loss: 1.4856 - val_loss: 1.4510
# Epoch 7/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 130ms/step - loss: 1.4418 - val_loss: 1.4162
# Epoch 8/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 129ms/step - loss: 1.4074 - val_loss: 1.3777
# Epoch 9/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 132ms/step - loss: 1.3775 - val_loss: 1.3507
# Epoch 10/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 133ms/step - loss: 1.3526 - val_loss: 1.3276
# Epoch 11/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 130ms/step - loss: 1.3301 - val_loss: 1.3041
# Epoch 12/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 131ms/step - loss: 1.3104 - val_loss: 1.2863
# Epoch 13/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 130ms/step - loss: 1.2939 - val_loss: 1.2708
# Epoch 14/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 133ms/step - loss: 1.2759 - val_loss: 1.2511
# Epoch 15/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 130ms/step - loss: 1.2591 - val_loss: 1.2312
# Epoch 16/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 131ms/step - loss: 1.2425 - val_loss: 1.2162
# Epoch 17/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 130ms/step - loss: 1.2288 - val_loss: 1.1976
# Epoch 18/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 129ms/step - loss: 1.2124 - val_loss: 1.1845
# Epoch 19/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 23s 134ms/step - loss: 1.1970 - val_loss: 1.1667
# Epoch 20/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 131ms/step - loss: 1.1823 - val_loss: 1.1520
# LSTM Total Training Time: 443.48s | Avg per epoch: 22.17s
# Epoch 1/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 19s 102ms/step - loss: 2.5526 - val_loss: 2.0449
# Epoch 2/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 21s 102ms/step - loss: 1.8751 - val_loss: 1.7214
# Epoch 3/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 18s 102ms/step - loss: 1.6414 - val_loss: 1.5518
# Epoch 4/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 18s 102ms/step - loss: 1.5143 - val_loss: 1.4551
# Epoch 5/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 17s 100ms/step - loss: 1.4384 - val_loss: 1.3886
# Epoch 6/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 18s 101ms/step - loss: 1.3865 - val_loss: 1.3432
# Epoch 7/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 18s 102ms/step - loss: 1.3435 - val_loss: 1.3018
# Epoch 8/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 17s 100ms/step - loss: 1.3117 - val_loss: 1.2650
# Epoch 9/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 19s 106ms/step - loss: 1.2789 - val_loss: 1.2371
# Epoch 10/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 17s 100ms/step - loss: 1.2503 - val_loss: 1.2055
# Epoch 11/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 18s 101ms/step - loss: 1.2220 - val_loss: 1.1738
# Epoch 12/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 17s 101ms/step - loss: 1.1938 - val_loss: 1.1419
# Epoch 13/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 17s 101ms/step - loss: 1.1660 - val_loss: 1.1130
# Epoch 14/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 18s 103ms/step - loss: 1.1392 - val_loss: 1.0838
# Epoch 15/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 17s 101ms/step - loss: 1.1113 - val_loss: 1.0512
# Epoch 16/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 18s 103ms/step - loss: 1.0827 - val_loss: 1.0190
# Epoch 17/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 17s 101ms/step - loss: 1.0528 - val_loss: 0.9924
# Epoch 18/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 17s 101ms/step - loss: 1.0234 - val_loss: 0.9593
# Epoch 19/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 18s 102ms/step - loss: 0.9933 - val_loss: 0.9291
# Epoch 20/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 17s 101ms/step - loss: 0.9644 - val_loss: 0.8968
# GRU Total Training Time: 356.89s | Avg per epoch: 17.84s
# Epoch 1/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 44s 254ms/step - loss: 0.8979 - val_loss: 0.0828
# Epoch 2/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 40s 250ms/step - loss: 0.0714 - val_loss: 0.0636
# Epoch 3/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 41s 254ms/step - loss: 0.0607 - val_loss: 0.0566
# Epoch 4/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 41s 251ms/step - loss: 0.0552 - val_loss: 0.0527
# Epoch 5/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 41s 251ms/step - loss: 0.0511 - val_loss: 0.0488
# Epoch 6/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 42s 257ms/step - loss: 0.0490 - val_loss: 0.0464
# Epoch 7/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 42s 254ms/step - loss: 0.0467 - val_loss: 0.0440
# Epoch 8/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 41s 251ms/step - loss: 0.0447 - val_loss: 0.0419
# Epoch 9/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 42s 257ms/step - loss: 0.0423 - val_loss: 0.0400
# Epoch 10/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 42s 252ms/step - loss: 0.0408 - val_loss: 0.0386
# Epoch 11/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 41s 252ms/step - loss: 0.0388 - val_loss: 0.0369
# Epoch 12/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 41s 256ms/step - loss: 0.0371 - val_loss: 0.0344
# Epoch 13/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 41s 252ms/step - loss: 0.0357 - val_loss: 0.0336
# Epoch 14/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 41s 251ms/step - loss: 0.0341 - val_loss: 0.0314
# Epoch 15/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 42s 256ms/step - loss: 0.0321 - val_loss: 0.0293
# Epoch 16/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 41s 253ms/step - loss: 0.0305 - val_loss: 0.0277
# Epoch 17/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 83s 261ms/step - loss: 0.0282 - val_loss: 0.0255
# Epoch 18/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 41s 253ms/step - loss: 0.0269 - val_loss: 0.0235
# Epoch 19/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 41s 252ms/step - loss: 0.0247 - val_loss: 0.0220
# Epoch 20/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 41s 254ms/step - loss: 0.0233 - val_loss: 0.0202
# BiRNN Total Training Time: 867.77s | Avg per epoch: 43.39s
#
# === Training Time Comparison ===
# Model      Total Time (s)       Avg/Epoch (s)
# LSTM       443.48               22.17
# GRU        356.89               17.84
# BiRNN      867.77               43.39

# %%
# Train stacked LSTM
model_stacked_lstm = build_stacked_lstm_model(VOCAB_SIZE, EMBEDDING_DIM, RNN_UNITS, BATCH_SIZE)
print("=== Stacked LSTM Summary ===")
model_stacked_lstm.summary()

start = time.time()
history_stacked_lstm = compile_and_train(model_stacked_lstm, path="stacked_lstm_checkpoints", EPOCHS=20)
stacked_time = time.time() - start
print(f"Stacked LSTM Training Time: {stacked_time:.2f}s | Avg per epoch: {stacked_time/20:.2f}s")
# Out:
# === Stacked LSTM Summary ===
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_10 (Embedding)        │ (64, None, 256)        │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_9 (LSTM)                   │ (64, None, 1024)       │     5,246,976 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_10 (LSTM)                  │ (64, None, 1024)       │     8,392,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (64, None, 66)         │        67,650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,724,226 (52.35 MB)
#  Trainable params: 13,724,226 (52.35 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 56s 318ms/step - loss: 2.7208 - val_loss: 2.1139
# Epoch 2/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 48s 301ms/step - loss: 1.8736 - val_loss: 1.6773
# Epoch 3/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 48s 300ms/step - loss: 1.5893 - val_loss: 1.4930
# Epoch 4/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 49s 305ms/step - loss: 1.4615 - val_loss: 1.3979
# Epoch 5/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 49s 306ms/step - loss: 1.3859 - val_loss: 1.3327
# Epoch 6/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 49s 304ms/step - loss: 1.3331 - val_loss: 1.2883
# Epoch 7/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 49s 302ms/step - loss: 1.2886 - val_loss: 1.2427
# Epoch 8/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 49s 301ms/step - loss: 1.2493 - val_loss: 1.1960
# Epoch 9/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 49s 301ms/step - loss: 1.2109 - val_loss: 1.1559
# Epoch 10/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 49s 301ms/step - loss: 1.1742 - val_loss: 1.1165
# Epoch 11/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 48s 301ms/step - loss: 1.1357 - val_loss: 1.0710
# Epoch 12/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 49s 303ms/step - loss: 1.0961 - val_loss: 1.0322
# Epoch 13/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 48s 301ms/step - loss: 1.0535 - val_loss: 0.9836
# Epoch 14/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 48s 301ms/step - loss: 1.0082 - val_loss: 0.9364
# Epoch 15/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 49s 303ms/step - loss: 0.9602 - val_loss: 0.8841
# Epoch 16/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 49s 305ms/step - loss: 0.9129 - val_loss: 0.8387
# Epoch 17/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 49s 304ms/step - loss: 0.8638 - val_loss: 0.7884
# Epoch 18/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 49s 305ms/step - loss: 0.8147 - val_loss: 0.7317
# Epoch 19/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 49s 300ms/step - loss: 0.7646 - val_loss: 0.6814
# Epoch 20/20
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 49s 302ms/step - loss: 0.7156 - val_loss: 0.6367
# Stacked LSTM Training Time: 983.37s | Avg per epoch: 49.17s

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

for ax, history, name in zip(axes, [history_lstm, history_gru, history_birnn], ['LSTM', 'GRU', 'BiRNN']):
    ax.plot(history.history['loss'], label='Train')
    ax.plot(history.history['val_loss'], label='Val')
    ax.set_title(name)
    ax.set_xlabel('Epoch')
    ax.set_ylabel('Loss')
    ax.legend()

plt.tight_layout()
plt.show()

# %%
# Choose model type
model_type = "GRU"

if model_type == "LSTM":
    model = build_lstm_model(VOCAB_SIZE, EMBEDDING_DIM, RNN_UNITS, BATCH_SIZE)
elif model_type == "GRU":
    model = build_gru_model(VOCAB_SIZE, EMBEDDING_DIM, RNN_UNITS, BATCH_SIZE)
elif model_type == "BiLSTM":
    model = build_birnn_model(VOCAB_SIZE, EMBEDDING_DIM, RNN_UNITS, BATCH_SIZE)

print(f"Using {model_type} model for generation.")
# Out:
# Using GRU model for generation.

# %% [markdown]
# # Generate Text Using the Model

# %%
class OneStepTextGenerator(tf.keras.Model):
    def __init__(self, model, chars_from_ids, ids_from_chars, temperature=1.0):
        """
        Initializes the OneStepTextGenerator.

        Parameters:
        - model: Trained text generation model (e.g., LSTM or GRU).
        - chars_from_ids: Function mapping character IDs to characters.
        - ids_from_chars: Function mapping characters to their respective IDs.
        - temperature (float): Controls randomness in text generation.
          -> Higher temperature (> 1.0): Produces more diverse and unpredictable text.
          -> Lower temperature (< 1.0): Makes the model more confident but results in repetitive text.
          -> Temperature = 1.0: Standard behavior without biasing randomness.
        """
        super().__init__()
        self.model = model
        self.chars_from_ids = chars_from_ids
        self.ids_from_chars = ids_from_chars
        self.temperature = temperature

    def generate_text(self, start_string, num_generate=1000):
        """
        Generates text one character at a time based on a starting string.

        Parameters:
        - start_string (str): Initial text prompt.
        - num_generate (int): Number of characters to generate.

        Returns:
        - str: Generated text.
        """
        # Convert start string to tensor representation
        input_eval = tf.expand_dims(self.ids_from_chars(tf.strings.unicode_split(start_string, 'UTF-8')), 0)
        text_generated = []

        # Initial hidden state (None allows automatic initialization)
        states = None

        for _ in range(num_generate):
            # Get model predictions and hidden state
            # predictions, states = self.model(input_eval, states=states, return_state=True)
            predictions = self.model(input_eval)

            # Adjust predictions using temperature
            predictions = predictions[:, -1, :] / self.temperature

            # Sample the next character ID from a probability distribution
            predicted_id = tf.random.categorical(predictions, num_samples=1)[-1, 0].numpy()

            # Use the predicted ID as next input
            input_eval = tf.expand_dims([predicted_id], 0)

            # Convert ID back to character and append to output
            text_generated.append(self.chars_from_ids(predicted_id).numpy().decode('utf-8'))

        return start_string + ''.join(text_generated)

# %% [markdown]
# # Evaluate Model Performance

# %% [markdown]
# **1- Perplexity (PP)**
#
# TODO: Measures uncertainty in predicting next character for each model and leave the results in the Notebook.
#
# ***Lower values = better model***

# %%
def perplexity(logits, labels):
    loss = tf.keras.losses.sparse_categorical_crossentropy(labels, logits, from_logits=True)
    return np.exp(np.mean(loss))

def evaluate_model_perplexity(model, dataset):
    total_loss = 0.0
    total_tokens = 0

    for input_batch, label_batch in dataset:
        logits = model(input_batch, training=False)
        loss = perplexity(logits, label_batch)
        total_loss += np.log(loss)
        total_tokens += tf.size(label_batch).numpy()

    avg_loss = total_loss / total_tokens
    return np.exp(avg_loss)

# %%
pp_lstm = evaluate_model_perplexity(model_lstm, validation_dataset)
pp_gru = evaluate_model_perplexity(model_gru, validation_dataset)
pp_birnn = evaluate_model_perplexity(model_birnn, validation_dataset)

print(f"LSTM  Perplexity: {pp_lstm:.4f}")
print(f"GRU   Perplexity: {pp_gru:.4f}")
print(f"BiRNN Perplexity: {pp_birnn:.4f}")
# Out:
# LSTM  Perplexity: 1.0002
# GRU   Perplexity: 1.0001
# BiRNN Perplexity: 1.0000

# %% [markdown]
# **2- Text Coherence & Fluency**
#
# Subjective evaluation by examining generated text
#
# **TODO: Generate at least 3 Samples (one from each model) and leave them in the Notebook.**

# %%
# Rebuild models with batch_size=1 for inference
model_lstm_infer = build_lstm_model(VOCAB_SIZE, EMBEDDING_DIM, RNN_UNITS, batch_size=1)
model_lstm_infer.set_weights(model_lstm.get_weights())

model_gru_infer = build_gru_model(VOCAB_SIZE, EMBEDDING_DIM, RNN_UNITS, batch_size=1)
model_gru_infer.set_weights(model_gru.get_weights())

model_birnn_infer = build_birnn_model(VOCAB_SIZE, EMBEDDING_DIM, RNN_UNITS, batch_size=1, rnn_type="LSTM")
model_birnn_infer.set_weights(model_birnn.get_weights())

# Generate text using inference models
one_step_lstm  = OneStepTextGenerator(model_lstm_infer,  chars_from_ids, ids_from_chars, temperature=1.0)
one_step_gru   = OneStepTextGenerator(model_gru_infer,   chars_from_ids, ids_from_chars, temperature=1.0)
one_step_birnn = OneStepTextGenerator(model_birnn_infer, chars_from_ids, ids_from_chars, temperature=1.0)

print("=== LSTM Generated Text ===")
print(one_step_lstm.generate_text("ROMEO: ", num_generate=500))

print("\n=== GRU Generated Text ===")
print(one_step_gru.generate_text("ROMEO: ", num_generate=500))

print("\n=== BiRNN Generated Text ===")
print(one_step_birnn.generate_text("ROMEO: ", num_generate=500))
# Out:
# === LSTM Generated Text ===
# ROMEO: ZM&3qzQXxQX[UNK]$$$QP3QV$XQXxxx3&x&[UNK]$3qjQV&3z&[UNK]z3&[UNK][UNK]3Q&[UNK]gq33$[UNK]DJH&$3H&qaJQ3x&QQ$Qqx$J[UNK]qQ&VXz&[UNK]$[UNK]G$X3XVX3XV$$$$3[UNK]QQ[UNK]3V$zzX$3[UNK][UNK]Q&zz&[UNK][UNK]3$D&$Q3&$&[UNK][UNK]3zXz$&[UNK]QjX3[UNK]&Q3&&XXQ$$3$QQxX$$$Zx&3[UNK]&Qj&$X3$[UNK]XQ$$KQDq&&3$jK3Vz3[UNK]PxX$3$J3[UNK]JXQQNX$[UNK]jQ$xS[UNK]Jq3jP&P3X&JQ[UNK]XQQxP&[UNK][UNK]$Q$Q3&QQj$$3j3$$3qx&M[UNK]$Q&$$3bx$KQ[UNK]&xZX$QxVq[UNK]Y$$QxX3JQ[UNK]&$V[UNK]&$zQq3&Dg$$$$3[UNK][UNK]XZxxJC$[UNK][UNK]j$Q$$jY$QJJXj3b$3$Jq3&QxGzQQ&XDJ$Jz[UNK]PX$&$$Qckj[UNK]$Qj[UNK]Q&[UNK]$$33J[UNK]$3$3qX3q&&QZ&D$Q[UNK][UNK]XQ&Z3VVJ$$zvQ3[UNK]3QxS&j$3z3DVzXx[UNK][UNK]&[UNK]DXz$QQ&$3[UNK]XxG[UNK]Q$3Vx[UNK]$Z$3&$&&$X$[UNK]QgQqx$QJ&Jj3$$33x$$3$j&Qj
#
# === GRU Generated Text ===
# ROMEO: hear me speak.
#
# KING RICHARD III:
# Well, sir; you must
# contrive that murderous joint. You'ld take this land,
# With what honourable foul s ugress'st my flattererly.
#
# PRINCE EDWARD:
# If every day is three or grace. You urego him drawn,
# His purpose dangerous loud are grow, and sweetest thus;
# How hast thou at the field, against it cheers
# Come hither like the supply.
#
# ROMEO:
# I was forcy and merry at the rest,
# And mean place and queen:
# To whom a merchant's silter at, then
# let it be factor like a precise
#
#
# === BiRNN Generated Text ===
# ROMEO: BRBRBRBRBRBRBRBRBRBRBRBRBRBRD-D-D-D-D-D-D-D-D-D-D-D-D-z-z-z-z-z-z-z-z-z-z-z-z-z-z-z-z-z-z-z-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **3- BLEU Score**
#
# TODO: Measures similarity between generated and real text for each model and leave the results in the Notebook.

# %%
def compute_bleu(reference, generated):
    return sentence_bleu([list(reference)], list(generated))

def evaluate_model_bleu(model, dataset):
    bleu_scores = []

    for input_batch, label_batch in dataset:
        logits = model(input_batch, training=False)
        predictions = tf.argmax(logits, axis=-1)

        label_batch = label_batch.numpy()

        for pred_seq, true_seq in zip(predictions, label_batch):
            # Decode sequences to text
            pred_text = text_from_ids(pred_seq, chars_from_ids).numpy().decode('utf-8')
            true_text = text_from_ids(true_seq, chars_from_ids).numpy().decode('utf-8')

            # Compute BLEU score for each sample
            bleu = compute_bleu(true_text, pred_text)
            bleu_scores.append(bleu)

    return np.mean(bleu_scores)

# %%
bleu_lstm  = evaluate_model_bleu(model_lstm,  validation_dataset)
bleu_gru   = evaluate_model_bleu(model_gru,   validation_dataset)
bleu_birnn = evaluate_model_bleu(model_birnn, validation_dataset)

print(f"LSTM  BLEU Score: {bleu_lstm:.4f}")
print(f"GRU   BLEU Score: {bleu_gru:.4f}")
print(f"BiRNN BLEU Score: {bleu_birnn:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# LSTM  BLEU Score: 0.3860
# GRU   BLEU Score: 0.5051
# BiRNN BLEU Score: 0.9955

# %% [markdown]
# ## Discussion
#
# ### LSTM vs GRU
# [Write your comparison here after seeing results]
#
# ### Unidirectional vs Bidirectional
# [Write your comparison here after seeing results]
#
# ### Impact of Bidirectional RNNs on Text Generation
# [Write your discussion here]
